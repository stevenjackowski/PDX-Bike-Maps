# %% [markdown]
# # process_bike_counts

# %%
# imports
import pandas as pd
import geopandas as gpd
import numpy as np

# %% [markdown]
# ## Step 1 - Process Bike Counts Data
# The following code processes counts of bicycle traffic taken from this [link](https://docs.google.com/spreadsheets/d/1urP-ZA0Pd25_JZZ18hkGPlDEUQusBp49XmLzwpZ-2ag/edit#gid=864700651). Goal is to get the counts for each location as a row in a dataframe, then aggregate by sector (NW, SW, SE...).

# %%
FILE = 'data/Portland Bike Counts.csv'

df = pd.read_csv(FILE, header=1)

# %%
# Melt the dataframe so each row is a reading
df = df.melt(['Sector','Site #','Location'])
df
# Out:
#            Sector  Site #                                     Location  \
# 0          bridge       2                              Burnside Bridge
# 1          bridge       4                              Sellwood Bridge
# 2           north       6             N Fessenden & Peninsula Crossing
# 3           north       7                       N Interstate & Greeley
# 4           north       8                      N Interstate & Larrabee
# 5           north       9                      N Portsmouth & Houghton
# 6           north      10                        N Denver & Rosa Parks
# 7           north      11                        N Vancouver & Russell
# 8           north      12                         N Williams & Russell
# 9           north      13                          N Smith & St. Louis
# 10          north      14                          N Flint & Tillamook
# 11          north      15                      N Vancouver & Ainsworth
# 12          north      16                  N Willamette & Philadelphia
# 13          north      17              N Willamette & Waud Bluff Trail
# 14           east      18                  NE Marine Drive & PDX Trail
# 15      northeast      19                              NE Going & 37th
# 16      northeast      20                          NE Multnomah & 47th
# 17      northeast      21                           NE Siskiyou & 72nd
# 18           east      22                             NE Halsey & 92nd
# 19      northeast      23                            NE Broadway & 7th
# 20           east      24                           E Burnside & 122nd
# 21      northeast      25                            E Burnside & 74th
# 22      northeast      26                            NE Everett & 53rd
# 23           east      27                           NE Fremont & 122nd
# 24           east      28                            NE Halsey & 122nd
# 25           east      29                            NE Halsey & 148th
# 26      northeast      30                             NE Irving & 12th
# 27      northeast      31                             NE Irving & 20th
# 28      northeast      32                           NE Multnomah & 7th
# 29      northeast      33              NE Killingsworth & Portland Hwy
# ...           ...     ...                                          ...
# 5970    southeast     302                              SE Odgen & 67th
# 5971    northwest     303                            NW Johnson & 20th
# 5972  city center     304                              SW Alder & 18th
# 5973    southwest     305               SW Capitol Hwy & Dolph Ct/41st
# 5974         east     306                           NE Fremont & 102nd
# 5975         east     307                           NE Weidler & 106th
# 5976         east     308                        NE San Rafael & 132nd
# 5977         east     309                          NE Holladay & 114th
# 5978    southeast     310                            SE MLK & Morrison
# 5979    northwest     311                           NW Marshall & 16th
# 5980    southwest     312  SW Scholls Ferry Rd & Raab Rd/Humphrey Blvd
# 5981    northwest     313                            NW Overton & 11th
# 5982        north     314                           N Williams & Dekum
# 5983         east     315                         NE Tillamook & 102nd
# 5984        north     316                          N Tillamook & Flint
# 5985  city center     317                   SW Naito @ Morrison Bridge
# 5986  city center     318                            SW Naito & Ankeny
# 5987  city center     319                            SW Naito & Salmon
# 5988    southeast     320              SE Water & Morrison Bridge path
# 5989    southeast     321                        SE Foster & 77th/78th
# 5990    southeast     322                               SE Linn & 19th
# 5991    southeast     323                              SE Bybee & 32nd
# 5992        north     324                           N Fessenden & Burr
# 5993        north     325                    N Kilpatrick & Chautauqua
# 5994        north     326             N Whitaker & Denver (Delta Park)
# 5995        north     327          N Vancouver & Columbia Slough Trail
# 5996    southeast     328                             SE Belmont & 7th
# 5997        north     329                  N Williams & Rosa Parks Way
# 5998         east     330                            NE Glisan & 128th
# 5999         east     331                            NE Glisan & 156th
#
#            variable  value
# 0              2018  1,780
# 1              2018    735
# 2              2018    220
# 3              2018  1,420
# 4              2018  1,660
# 5              2018    200
# 6              2018    850
# 7              2018  4,705
# 8              2018  4,108
# 9              2018     20
# 10             2018    635
# 11             2018  1,265
# 12             2018    NaN
# 13             2018    NaN
# 14             2018    195
# 15             2018    900
# 16             2018    500
# 17             2018    145
# 18             2018    135
# 19             2018  1,595
# 20             2018    340
# 21             2018    570
# 22             2018  1,550
# 23             2018     95
# 24             2018    185
# 25             2018     55
# 26             2018  1,630
# 27             2018  1,000
# 28             2018  1,620
# 29             2018    NaN
# ...             ...    ...
# 5970  prior to 2000    NaN
# 5971  prior to 2000    NaN
# 5972  prior to 2000    NaN
# 5973  prior to 2000    NaN
# 5974  prior to 2000    NaN
# 5975  prior to 2000    NaN
# 5976  prior to 2000    NaN
# 5977  prior to 2000    NaN
# 5978  prior to 2000    NaN
# 5979  prior to 2000    NaN
# 5980  prior to 2000    NaN
# 5981  prior to 2000    NaN
# 5982  prior to 2000    NaN
# 5983  prior to 2000    NaN
# 5984  prior to 2000    NaN
# 5985  prior to 2000    NaN
# 5986  prior to 2000    NaN
# 5987  prior to 2000    NaN
# 5988  prior to 2000    NaN
# 5989  prior to 2000    NaN
# 5990  prior to 2000    NaN
# 5991  prior to 2000    NaN
# 5992  prior to 2000    NaN
# 5993  prior to 2000    NaN
# 5994  prior to 2000    NaN
# 5995  prior to 2000    NaN
# 5996  prior to 2000    NaN
# 5997  prior to 2000    NaN
# 5998  prior to 2000    NaN
# 5999  prior to 2000    NaN
#
# [6000 rows x 5 columns]

# %%
# Filter out NaNs and '-'s
df['value'] = pd.to_numeric(df['value'], errors='coerce', downcast='integer')
df = df[pd.notnull(df['value'])]

# %%
# Group by the sector
df_agg = df.groupby(['Sector','variable'])['value'].sum()
df_agg = df_agg.reset_index()
df_agg = df_agg.set_index('Sector')

# %%
# Collapse all of the years into a JSON object for each sector
df_agg = df_agg.groupby('Sector').apply(lambda x: x.set_index('variable').to_json(orient='columns'))

# %%
df_agg
# Out:
# Sector
# bridge         {"value":{"2001":965.0,"2003":690.0,"2006":500...
# city center    {"value":{"2000":1140.0,"2001":1590.0,"2002":9...
# east           {"value":{"2006":1115.0,"2007":2155.0,"2008":4...
# north          {"value":{"2000":2515.0,"2001":2825.0,"2003":3...
# northeast      {"value":{"2000":2130.0,"2001":2565.0,"2003":2...
# northwest      {"value":{"2000":710.0,"2001":255.0,"2002":445...
# southeast      {"value":{"2000":1375.0,"2001":3105.0,"2003":1...
# southwest      {"value":{"2000":490.0,"2001":485.0,"2003":720...
# dtype: object

# %% [markdown]
# # Step 2 - Generate GEOJSON File
#
# This code uses geopandas to generate a GEOJSON object using a shape file for Portland's boundaries, joined with the above dataset. Geopandas was difficult to install on Windows but I found [this](https://geoffboeing.com/2014/09/using-geopandas-windows/) link very helpful. Shape files downloaded from [here](https://gis-pdx.opendata.arcgis.com/datasets/portland-administrative-sextants).

# %%
FILE = 'data/Portland_Administrative_Sextants.shp'
OUT_FILE = 'vis/pdx_zones.geojson'

# Read the shape file with Portland boundaries
shp = gpd.read_file(FILE)

# %%
shp
# Out:
#    OBJECTID  FID_quadra PREFIX         acres    sqmiles  Quadrants  \
# 0         1           2     NW  14532.835938  22.707556  NorthWest
# 1         2           5     SE  28707.505859  44.855480  SouthEast
# 2         3           4     SW  14469.660156  22.608845      South
# 3         4           4     SW  14469.660156  22.608845  SouthWest
# 4         5           4     SW  14469.660156  22.608845  SouthWest
# 5         6           3      N  26102.648438  40.785385      North
# 6         7           3     NE  26102.648438  40.785385  NorthEast
#
#    FID_South_    Shape_Leng    Shape_Area  \
# 0          -1  68370.581202  1.628050e+08
# 1          -1  66324.738076  2.396703e+08
# 2           1  33350.409679  2.290833e+07
# 3          -1  54492.289907  1.062193e+08
# 4          -1   1863.970732  2.315196e+04
# 5          -1  55159.484521  1.570435e+08
# 6          -1  75437.454095  2.153998e+08
#
#                                             geometry
# 0  POLYGON ((-122.7925059896695 45.61975437764568...
# 1  POLYGON ((-122.6519986985515 45.52289597099575...
# 2  POLYGON ((-122.6703018158715 45.48586233144766...
# 3  POLYGON ((-122.6673597901969 45.52305133547165...
# 4  POLYGON ((-122.6658845867188 45.50341050137209...
# 5  POLYGON ((-122.6668008350709 45.52797063956169...
# 6  POLYGON ((-122.546027143023 45.57725776175279,...

# %%
shp['Quadrants'] = shp['Quadrants'].str.lower()

# %%
#shp
shp2 = shp.merge(df_agg.rename('Bike_Counts'), left_on='Quadrants', right_on='Sector', how='inner')

# %%
# Convert the shape file to GEOJSON format
shp2.to_file(OUT_FILE, driver='GeoJSON')
